# %% [markdown]
# # This file is for data cleansing only
# The data set we use here are:
# 1. Air quality data from Open data Bristol
# 2. EVs sale data from GOV.uk

# %% [markdown]
# ### Step1 : Import data

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df_evs = pd.read_csv('C:/Users/Admin/Desktop/DSMP/Raw data/Bristol car sales data -EV population.csv')
df_aq = pd.read_csv("C:/Users/Admin/Desktop/DSMP/Raw data/air-quality-data-continuous.csv", sep=";")

df_evs
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11788\720655564.py:2: DtypeWarning: Columns (20) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_aq = pd.read_csv("C:/Users/Admin/Desktop/DSMP/Raw data/air-quality-data-continuous.csv", sep=";")
#        Units              Fuel Keepership  ONS Sort [note 6]  \
# 0     Number  Battery electric    Company                  1
# 1     Number  Battery electric    Company                  2
# 2     Number  Battery electric    Company                  3
# 3     Number  Battery electric    Company                  4
# 4     Number  Battery electric    Company                  5
# ...      ...               ...        ...                ...
# 6697  Number             Total      Total                460
# 6698  Number             Total      Total                461
# 6699  Number             Total      Total                462
# 6700  Number             Total      Total                463
# ...

# %% [markdown]
# ### Step2 : Clean data
# ### 2.1 Clean EVs data

# %%
# drop uneccessary columns
df_evs = df_evs.drop(columns=['ONS Code [note 6]','ONS Sort [note 6]','Units'],axis=1)

# Filter data in columns
df_evs = df_evs.loc[df_evs['Keepership'] == 'Total']
df_evs = df_evs.loc[df_evs['ONS Geography [note 6]'] == '   Bristol, City of']
df_evs = df_evs.loc[df_evs['Fuel'] == 'Battery electric']

# Remove comma in data and change city name
df_evs = df_evs.replace('   Bristol, City of', 'Bristol', regex=True)
df_evs = df_evs.replace(',', '', regex=True)

df_evs
# Out:
#                   Fuel Keepership ONS Geography [note 6] 2022 Q3 2022 Q2  \
# 1263  Battery electric      Total                Bristol    2208    2016
#
#      2022 Q1 2021 Q4 2021 Q3 2021 Q2 2021 Q1  ... 2014 Q1 2013 Q4 2013 Q3  \
# 1263    1888    1722    1553    1357    1189  ...      77      48      42
#
#      2013 Q2 2013 Q1 2012 Q4 2012 Q3 2012 Q2 2012 Q1 2011 Q4
# 1263      36      33      36      34      30      26      26
#
# [1 rows x 47 columns]

# %%
# Get a list of the old column names
old_columns = list(df_evs.columns[3:])

# Melt the DataFrame using the old column names as the values in the "Date" column
melted_evs = df_evs.melt(id_vars=['Fuel', 'Keepership', 'ONS Geography [note 6]'], var_name='Date', value_name='Volume', value_vars=old_columns)

melted_evs
# Out:
#                 Fuel Keepership ONS Geography [note 6]     Date Volume
# 0   Battery electric      Total                Bristol  2022 Q3   2208
# 1   Battery electric      Total                Bristol  2022 Q2   2016
# 2   Battery electric      Total                Bristol  2022 Q1   1888
# 3   Battery electric      Total                Bristol  2021 Q4   1722
# 4   Battery electric      Total                Bristol  2021 Q3   1553
# 5   Battery electric      Total                Bristol  2021 Q2   1357
# 6   Battery electric      Total                Bristol  2021 Q1   1189
# 7   Battery electric      Total                Bristol  2020 Q4   1114
# 8   Battery electric      Total                Bristol  2020 Q3    930
# 9   Battery electric      Total                Bristol  2020 Q2    782
# 10  Battery electric      Total                Bristol  2020 Q1    719
# 11  Battery electric      Total                Bristol  2019 Q4    624
# ...

# %%
# Extract year and quarter from "Date" column
melted_evs["Year"] = melted_evs["Date"].str.split(" ").str[0]
melted_evs["Quarter"] = melted_evs["Date"].str.split(" ").str[1]

# Convert quarter to month
quarter_dict = {"Q1": "03", "Q2": "06", "Q3": "09", "Q4": "12"}
melted_evs["Month"] = melted_evs["Quarter"].map(quarter_dict)

# Convert year, month and day to datetime
melted_evs["Date"] = pd.to_datetime(melted_evs["Year"] + melted_evs["Month"] + "01", format="%Y%m%d") + pd.offsets.QuarterEnd()

# Calculate start date of quarter
melted_evs["Quarter Start"] = melted_evs["Date"] - pd.offsets.MonthBegin(3)

# Drop unnecessary columns
melted_evs = melted_evs.drop(["Year", "Quarter", "Month"], axis=1)

# Rename the columns
melted_evs = melted_evs.rename(columns={"ONS Geography [note 6]": "City"})
melted_evs = melted_evs.rename(columns={"Date": "Quarter End"})

# Drop Keepership column
melted_evs = melted_evs.drop(columns='Keepership',axis=1)

# Re columns index
melted_evs = melted_evs.reindex(columns=['Fuel', 'City', 'Volume', 'Quarter Start', 'Quarter End'])

# change data frame name
df_evs = melted_evs
df_evs
# Out:
#                 Fuel     City Volume Quarter Start Quarter End
# 0   Battery electric  Bristol   2208    2022-07-01  2022-09-30
# 1   Battery electric  Bristol   2016    2022-04-01  2022-06-30
# 2   Battery electric  Bristol   1888    2022-01-01  2022-03-31
# 3   Battery electric  Bristol   1722    2021-10-01  2021-12-31
# 4   Battery electric  Bristol   1553    2021-07-01  2021-09-30
# 5   Battery electric  Bristol   1357    2021-04-01  2021-06-30
# 6   Battery electric  Bristol   1189    2021-01-01  2021-03-31
# 7   Battery electric  Bristol   1114    2020-10-01  2020-12-31
# 8   Battery electric  Bristol    930    2020-07-01  2020-09-30
# 9   Battery electric  Bristol    782    2020-04-01  2020-06-30
# 10  Battery electric  Bristol    719    2020-01-01  2020-03-31
# 11  Battery electric  Bristol    624    2019-10-01  2019-12-31
# 12  Battery electric  Bristol    539    2019-07-01  2019-09-30
# 13  Battery electric  Bristol    453    2019-04-01  2019-06-30
# ...

# %% [markdown]
# ### 2.2 Clean Air quality data

# %%
# Check data data info
df_aq.info()
df_aq
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1545432 entries, 0 to 1545431
# Data columns (total 23 columns):
#  #   Column           Non-Null Count    Dtype
# ---  ------           --------------    -----
#  0   Date Time        1545425 non-null  object
#  1   NOx              1410954 non-null  float64
#  2   NO2              1408172 non-null  float64
#  3   NO               1417289 non-null  float64
#  4   SiteID           1545432 non-null  int64
#  5   PM10             342257 non-null   float64
#  6   NVPM10           88165 non-null    float64
#  7   VPM10            88158 non-null    float64
#  8   NVPM2.5          71978 non-null    float64
#  9   PM2.5            138205 non-null   float64
#  10  VPM2.5           71978 non-null    float64
#  11  CO               195930 non-null   float64
#  12  O3               258516 non-null   float64
#  13  SO2              156179 non-null   float64
#  14  Temperature      104430 non-null   float64
# ...

# %%
# Drop unneccessary data
df_aq = df_aq.loc[:, ['Date Time', 'NOx', 'Location', 'geo_point_2d']]

# Split data into lat and long
df_aq[["Latitude", "Longitude"]] = df_aq["geo_point_2d"].str.split(",", expand=True)

# Drop geo_point_2d 
df_aq = df_aq.drop(columns='geo_point_2d', axis=1)

# Convert the "Date Time" column to datetime type
df_aq["Date Time"] = pd.to_datetime(df_aq["Date Time"])

# Extract the date and time components
df_aq["Date"] = df_aq["Date Time"].dt.date
df_aq["Time"] = df_aq["Date Time"].dt.time

# Drop the original "Date Time" column
df_aq.drop(columns=["Date Time"], inplace=True)

df_aq
# Out:
#                 NOx              Location            Latitude  \
# 0        122.250000        Colston Avenue  51.455269382758324
# 1         42.250000        Colston Avenue  51.455269382758324
# 2         82.000000        Colston Avenue  51.455269382758324
# 3        357.250000        Colston Avenue  51.455269382758324
# 4        194.500000        Colston Avenue  51.455269382758324
# ...             ...                   ...                 ...
# 1545427  170.341063        Colston Avenue  51.455269382758324
# 1545428   61.658469    Marlborough Street   51.45914197176008
# 1545429  115.663221  Parson Street School   51.43267570732794
# 1545430   73.337470        Fishponds Road   51.47804497171107
# 1545431   37.780375  Parson Street School   51.43267570732794
#
#                    Longitude        Date      Time
# 0         -2.596648828557916  2019-04-29  23:00:00
# 1         -2.596648828557916  2019-04-30  03:00:00
# 2         -2.596648828557916  2019-05-01  06:00:00
# ...

# %%
# Check the data
df_aq.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1545432 entries, 0 to 1545431
# Data columns (total 6 columns):
#  #   Column     Non-Null Count    Dtype
# ---  ------     --------------    -----
#  0   NOx        1410954 non-null  float64
#  1   Location   1545432 non-null  object
#  2   Latitude   1545432 non-null  object
#  3   Longitude  1545432 non-null  object
#  4   Date       1545425 non-null  object
#  5   Time       1545425 non-null  object
# dtypes: float64(1), object(5)
# memory usage: 70.7+ MB

# %%
# Drop Null value of NOx
df_aq = df_aq.dropna()
df_aq
# Out:
#                 NOx              Location            Latitude  \
# 0        122.250000        Colston Avenue  51.455269382758324
# 1         42.250000        Colston Avenue  51.455269382758324
# 2         82.000000        Colston Avenue  51.455269382758324
# 3        357.250000        Colston Avenue  51.455269382758324
# 4        194.500000        Colston Avenue  51.455269382758324
# ...             ...                   ...                 ...
# 1545427  170.341063        Colston Avenue  51.455269382758324
# 1545428   61.658469    Marlborough Street   51.45914197176008
# 1545429  115.663221  Parson Street School   51.43267570732794
# 1545430   73.337470        Fishponds Road   51.47804497171107
# 1545431   37.780375  Parson Street School   51.43267570732794
#
#                    Longitude        Date      Time
# 0         -2.596648828557916  2019-04-29  23:00:00
# 1         -2.596648828557916  2019-04-30  03:00:00
# 2         -2.596648828557916  2019-05-01  06:00:00
# ...

# %% [markdown]
# ### Step3: Merge both data frame by following the condition below
# 1. If the "Date" column from df_aq is in the range of date between "Quarter start" and "Quarter End" from df_evs, we will merge all column of df_evs  with df_aq
# 2. If the "Date" column from df_aq is not match in the range of date between "Quarter start" and "Quarter End" from df_evs, we will drop that row

# %%
import pandas as pd

# Convert the date columns to datetime objects
df_evs['Quarter Start'] = pd.to_datetime(df_evs['Quarter Start'])
df_evs['Quarter End'] = pd.to_datetime(df_evs['Quarter End'])
df_aq['Date'] = pd.to_datetime(df_aq['Date'])

# Merge the dataframes based on the date ranges
df_merged = pd.merge_asof(df_aq.sort_values('Date'), df_evs.sort_values('Quarter Start'),
                          left_on='Date', right_on='Quarter Start')

# Drop any rows from the merged dataframe where the date is not within the quarter date range
mask = (df_merged['Quarter Start'] <= df_merged['Date']) & (df_merged['Quarter End'] >= df_merged['Date'])
df_merged = df_merged[mask]

df_merged
# Out:
# C:\Users\Admin\AppData\Local\Temp\ipykernel_11788\2158651479.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_aq['Date'] = pd.to_datetime(df_aq['Date'])
#               NOx           Location            Latitude  \
# 748440    71.5000         Wells Road       51.4278638883
# 748441   143.5000         Wells Road       51.4278638883
# 748442    54.5000         Wells Road       51.4278638883
# 748443   194.7500     Fishponds Road       51.4780449714
# 748444    29.0000          Bath Road       51.4425372726
# ...           ...                ...                 ...
# 1386121   13.0000     Fishponds Road   51.47804497171107
# 1386122  106.0927         Temple Way  51.457949713224494
# ...

# %%
# Re columns index
df_merged = df_merged.reindex(columns=['Fuel', 'City', 'Date', 'Time', 'Quarter Start', 'Quarter End', 'Volume', 'NOx', 'Location', 'Latitude', 'Longitude'])

# Rename column
df_merged = df_merged.rename(columns={"Volume": "EVs Volume"})

df_merged
# Out:
#                      Fuel     City       Date      Time Quarter Start  \
# 748440   Battery electric  Bristol 2011-10-01  21:00:00    2011-10-01
# 748441   Battery electric  Bristol 2011-10-01  18:00:00    2011-10-01
# 748442   Battery electric  Bristol 2011-10-01  22:00:00    2011-10-01
# 748443   Battery electric  Bristol 2011-10-01  08:00:00    2011-10-01
# 748444   Battery electric  Bristol 2011-10-01  18:00:00    2011-10-01
# ...                   ...      ...        ...       ...           ...
# 1386121  Battery electric  Bristol 2022-09-30  18:00:00    2022-07-01
# 1386122  Battery electric  Bristol 2022-09-30  10:00:00    2022-07-01
# 1386123  Battery electric  Bristol 2022-09-30  15:00:00    2022-07-01
# 1386124  Battery electric  Bristol 2022-09-30  12:00:00    2022-07-01
# 1386125  Battery electric  Bristol 2022-09-30  12:00:00    2022-07-01
#
#         Quarter End EVs Volume       NOx           Location  \
# 748440   2011-12-31         26   71.5000         Wells Road
# ...

# %%
df_merged.to_csv('DSMP_EVs_AQ.csv')
